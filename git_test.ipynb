# %%
print('hello world')
# Out:
# hello world

# %%
#푸시 할 때

# %%
from google.colab import drive
drive.mount('/content/drive')

# 레포지토리이름 수정!

# !git config --global user.email 'dbsxodnd816@naver.com'
# !git config --global user.name 'AIKingman'

# !git add .
# !git commit -m 'success'
# !git push
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [main 25e9092] success
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite git_test.ipynb (60%)
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.12 KiB | 287.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# remote: This repository moved. Please use the new location:
# remote:   https://github.com/AIkingman/test.git
# To https://github.com/AIKingman/test.git
#    010aa47..25e9092  main -> main

# %%
cd /content/drive/MyDrive/git_plus/test
# Out:
# /content/drive/MyDrive/git_plus/test
